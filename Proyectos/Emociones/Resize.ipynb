# %% [markdown]
# # Resize

# %%
# Importar las bibliotecas necesarias
import numpy as np
import cv2 as cv
import os

# Definir la ruta a la carpeta con las imágenes
folder_path = 'C:\\Users\\alanj\\Desktop\\IA\\Proyectos\\Emociones\\DataSet\\Sorprendidos'  # Reemplaza con la ruta correcta
# Definir la función para redimensionar imágenes
def resize_images(folder_path, size=(80, 80)):
    # Verificar si la carpeta existe
    if not os.path.exists(folder_path):
        print(f"La carpeta {folder_path} no existe.")
        return
    
    # Iterar sobre todos los archivos en la carpeta
    for filename in os.listdir(folder_path):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            try:
                img_path = os.path.join(folder_path, filename)
                img = cv.imread(img_path)
                if img is not None:
                    # Redimensionar la imagen
                    img_resized = cv.resize(img, size, interpolation=cv.INTER_AREA)
                    # Sobrescribir la imagen original con la imagen redimensionada
                    cv.imwrite(img_path, img_resized)
                    print(f"Imagen {filename} redimensionada a {size}.")
                else:
                    print(f"No se pudo leer la imagen {filename}.")
            except Exception as e:
                print(f"No se pudo redimensionar la imagen {filename}: {e}")


# Llamar a la función para redimensionar imágenes
resize_images(folder_path)
# Out:
# Imagen 0edgarsorprendido.png redimensionada a (80, 80).
# Imagen 1.png redimensionada a (80, 80).
# Imagen 10.png redimensionada a (80, 80).
# Imagen 100.png redimensionada a (80, 80).
# Imagen 101.png redimensionada a (80, 80).
# Imagen 102.png redimensionada a (80, 80).
# Imagen 10edgarsorprendido.png redimensionada a (80, 80).
# Imagen 11.png redimensionada a (80, 80).
# Imagen 11edgarsorprendido.png redimensionada a (80, 80).
# Imagen 12.png redimensionada a (80, 80).
# Imagen 12edgarsorprendido.png redimensionada a (80, 80).
# Imagen 13.png redimensionada a (80, 80).
# Imagen 13edgarsorprendido.png redimensionada a (80, 80).
# Imagen 14.png redimensionada a (80, 80).
# Imagen 14edgarsorprendido.png redimensionada a (80, 80).
# Imagen 15.png redimensionada a (80, 80).
# Imagen 15edgarsorprendido.png redimensionada a (80, 80).
# Imagen 16.png redimensionada a (80, 80).
# Imagen 16edgarsorprendido.png redimensionada a (80, 80).
# Imagen 17.png redimensionada a (80, 80).
# Imagen 17edgarsorprendido.png redimensionada a (80, 80).
# Imagen 18.png redimensionada a (80, 80).
# Imagen 18edgarsorprendido.png redimensionada a (80, 80).
# Imagen 19.png redimensionada a (80, 80).
# Imagen 191.png redimensionada a (80, 80).
# Imagen 192.png redimensionada a (80, 80).
# Imagen 193.png redimensionada a (80, 80).
# Imagen 194.png redimensionada a (80, 80).
# Imagen 195.png redimensionada a (80, 80).
# Imagen 196.png redimensionada a (80, 80).
# Imagen 197.png redimensionada a (80, 80).
# Imagen 198.png redimensionada a (80, 80).
# Imagen 199.png redimensionada a (80, 80).
# Imagen 19edgarsorprendido.png redimensionada a (80, 80).
# Imagen 1edgarsorprendido.png redimensionada a (80, 80).
# Imagen 2.png redimensionada a (80, 80).
# Imagen 20.png redimensionada a (80, 80).
# Imagen 200.png redimensionada a (80, 80).
# Imagen 201.png redimensionada a (80, 80).
# Imagen 202.png redimensionada a (80, 80).
# Imagen 203.png redimensionada a (80, 80).
# Imagen 204.png redimensionada a (80, 80).
# Imagen 205.png redimensionada a (80, 80).
# Imagen 206.png redimensionada a (80, 80).
# Imagen 207.png redimensionada a (80, 80).
# Imagen 208.png redimensionada a (80, 80).
# Imagen 209.png redimensionada a (80, 80).
# Imagen 21.png redimensionada a (80, 80).
# Imagen 210.png redimensionada a (80, 80).
# Imagen 211.png redimensionada a (80, 80).
# Imagen 212.png redimensionada a (80, 80).
# Imagen 213.png redimensionada a (80, 80).
# Imagen 214.png redimensionada a (80, 80).
# Imagen 215.png redimensionada a (80, 80).
# Imagen 216.png redimensionada a (80, 80).
# Imagen 217.png redimensionada a (80, 80).
# Imagen 218.png redimensionada a (80, 80).
# Imagen 22.png redimensionada a (80, 80).
# Imagen 220.png redimensionada a (80, 80).
# Imagen 221.png redimensionada a (80, 80).
# Imagen 222.png redimensionada a (80, 80).
# Imagen 223.png redimensionada a (80, 80).
# Imagen 225.png redimensionada a (80, 80).
# Imagen 226.png redimensionada a (80, 80).
# Imagen 227.png redimensionada a (80, 80).
# Imagen 228.png redimensionada a (80, 80).
# Imagen 23.png redimensionada a (80, 80).
# Imagen 230.png redimensionada a (80, 80).
# Imagen 232.png redimensionada a (80, 80).
# Imagen 233.png redimensionada a (80, 80).
# Imagen 234.png redimensionada a (80, 80).
# Imagen 235.png redimensionada a (80, 80).
# Imagen 236.png redimensionada a (80, 80).
# Imagen 237.png redimensionada a (80, 80).
# Imagen 238.png redimensionada a (80, 80).
# Imagen 239.png redimensionada a (80, 80).
# Imagen 24.png redimensionada a (80, 80).
# Imagen 240.png redimensionada a (80, 80).
# Imagen 241.png redimensionada a (80, 80).
# Imagen 242.png redimensionada a (80, 80).
# Imagen 243.png redimensionada a (80, 80).
# Imagen 244.png redimensionada a (80, 80).
# Imagen 245.png redimensionada a (80, 80).
# Imagen 246.png redimensionada a (80, 80).
# Imagen 247.png redimensionada a (80, 80).
# Imagen 248.png redimensionada a (80, 80).
# Imagen 249.png redimensionada a (80, 80).
# Imagen 25.png redimensionada a (80, 80).
# Imagen 250.png redimensionada a (80, 80).
# Imagen 251.png redimensionada a (80, 80).
# Imagen 252.png redimensionada a (80, 80).
# Imagen 253.png redimensionada a (80, 80).
# Imagen 254.png redimensionada a (80, 80).
# Imagen 255.png redimensionada a (80, 80).
# Imagen 256.png redimensionada a (80, 80).
# Imagen 257.png redimensionada a (80, 80).
# Imagen 258.png redimensionada a (80, 80).
# Imagen 259.png redimensionada a (80, 80).
# Imagen 26.png redimensionada a (80, 80).
# Imagen 260.png redimensionada a (80, 80).
# Imagen 261.png redimensionada a (80, 80).
# Imagen 262.png redimensionada a (80, 80).
# Imagen 263.png redimensionada a (80, 80).
# Imagen 264.png redimensionada a (80, 80).
# Imagen 265.png redimensionada a (80, 80).
# Imagen 266.png redimensionada a (80, 80).
# Imagen 267.png redimensionada a (80, 80).
# Imagen 268.png redimensionada a (80, 80).
# Imagen 269.png redimensionada a (80, 80).
# Imagen 27.png redimensionada a (80, 80).
# Imagen 270.png redimensionada a (80, 80).
# Imagen 271.png redimensionada a (80, 80).
# Imagen 272.png redimensionada a (80, 80).
# Imagen 273.png redimensionada a (80, 80).
# Imagen 274.png redimensionada a (80, 80).
# Imagen 275.png redimensionada a (80, 80).
# Imagen 276.png redimensionada a (80, 80).
# Imagen 277.png redimensionada a (80, 80).
# Imagen 278.png redimensionada a (80, 80).
# Imagen 279.png redimensionada a (80, 80).
# Imagen 28.png redimensionada a (80, 80).
# Imagen 280.png redimensionada a (80, 80).
# Imagen 281.png redimensionada a (80, 80).
# Imagen 282.png redimensionada a (80, 80).
# Imagen 283.png redimensionada a (80, 80).
# Imagen 284.png redimensionada a (80, 80).
# Imagen 285.png redimensionada a (80, 80).
# Imagen 286.png redimensionada a (80, 80).
# Imagen 287.png redimensionada a (80, 80).
# Imagen 288.png redimensionada a (80, 80).
# Imagen 289.png redimensionada a (80, 80).
# Imagen 29.png redimensionada a (80, 80).
# Imagen 290.png redimensionada a (80, 80).
# Imagen 291.png redimensionada a (80, 80).
# Imagen 292.png redimensionada a (80, 80).
# Imagen 293.png redimensionada a (80, 80).
# Imagen 294.png redimensionada a (80, 80).
# Imagen 295.png redimensionada a (80, 80).
# Imagen 296.png redimensionada a (80, 80).
# Imagen 297.png redimensionada a (80, 80).
# Imagen 298.png redimensionada a (80, 80).
# Imagen 299.png redimensionada a (80, 80).
# Imagen 2edgarsorprendido.png redimensionada a (80, 80).
# Imagen 3.png redimensionada a (80, 80).
# Imagen 30.png redimensionada a (80, 80).
# Imagen 300.png redimensionada a (80, 80).
# Imagen 301.png redimensionada a (80, 80).
# Imagen 302.png redimensionada a (80, 80).
# Imagen 303.png redimensionada a (80, 80).
# Imagen 304.png redimensionada a (80, 80).
# Imagen 305.png redimensionada a (80, 80).
# Imagen 306.png redimensionada a (80, 80).
# Imagen 307.png redimensionada a (80, 80).
# Imagen 308.png redimensionada a (80, 80).
# Imagen 309.png redimensionada a (80, 80).
# Imagen 31.png redimensionada a (80, 80).
# Imagen 32.png redimensionada a (80, 80).
# Imagen 33.png redimensionada a (80, 80).
# Imagen 34.png redimensionada a (80, 80).
# Imagen 35.png redimensionada a (80, 80).
# Imagen 36.png redimensionada a (80, 80).
# Imagen 37.png redimensionada a (80, 80).
# Imagen 38.png redimensionada a (80, 80).
# Imagen 389edgarsorprendido.png redimensionada a (80, 80).
# Imagen 39.png redimensionada a (80, 80).
# Imagen 390edgarsorprendido.png redimensionada a (80, 80).
# Imagen 391edgarsorprendido.png redimensionada a (80, 80).
# Imagen 392edgarsorprendido.png redimensionada a (80, 80).
# Imagen 393edgarsorprendido.png redimensionada a (80, 80).
# Imagen 394edgarsorprendido.png redimensionada a (80, 80).
# Imagen 395edgarsorprendido.png redimensionada a (80, 80).
# Imagen 396edgarsorprendido.png redimensionada a (80, 80).
# Imagen 397edgarsorprendido.png redimensionada a (80, 80).
# Imagen 398edgarsorprendido.png redimensionada a (80, 80).
# Imagen 399edgarsorprendido.png redimensionada a (80, 80).
# Imagen 3edgarsorprendido.png redimensionada a (80, 80).
# Imagen 4.png redimensionada a (80, 80).
# Imagen 40.png redimensionada a (80, 80).
# Imagen 400edgarsorprendido.png redimensionada a (80, 80).
# Imagen 401edgarsorprendido.png redimensionada a (80, 80).
# Imagen 402edgarsorprendido.png redimensionada a (80, 80).
# Imagen 403edgarsorprendido.png redimensionada a (80, 80).
# Imagen 404edgarsorprendido.png redimensionada a (80, 80).
# Imagen 405edgarsorprendido.png redimensionada a (80, 80).
# Imagen 406edgarsorprendido.png redimensionada a (80, 80).
# Imagen 407edgarsorprendido.png redimensionada a (80, 80).
# Imagen 408edgarsorprendido.png redimensionada a (80, 80).
# Imagen 409edgarsorprendido.png redimensionada a (80, 80).
# Imagen 41.png redimensionada a (80, 80).
# Imagen 410edgarsorprendido.png redimensionada a (80, 80).
# Imagen 411edgarsorprendido.png redimensionada a (80, 80).
# Imagen 412edgarsorprendido.png redimensionada a (80, 80).
# Imagen 413edgarsorprendido.png redimensionada a (80, 80).
# Imagen 42.png redimensionada a (80, 80).
# Imagen 43.png redimensionada a (80, 80).
# Imagen 44.png redimensionada a (80, 80).
# Imagen 45.png redimensionada a (80, 80).
# Imagen 46.png redimensionada a (80, 80).
# Imagen 47.png redimensionada a (80, 80).
# Imagen 48.png redimensionada a (80, 80).
# Imagen 49.png redimensionada a (80, 80).
# Imagen 4edgarsorprendido.png redimensionada a (80, 80).
# Imagen 5.png redimensionada a (80, 80).
# Imagen 50.png redimensionada a (80, 80).
# Imagen 51.png redimensionada a (80, 80).
# Imagen 52.png redimensionada a (80, 80).
# Imagen 53.png redimensionada a (80, 80).
# Imagen 54.png redimensionada a (80, 80).
# Imagen 55.png redimensionada a (80, 80).
# Imagen 56.png redimensionada a (80, 80).
# Imagen 57.png redimensionada a (80, 80).
# Imagen 58.png redimensionada a (80, 80).
# Imagen 59.png redimensionada a (80, 80).
# Imagen 5edgarsorprendido.png redimensionada a (80, 80).
# Imagen 6.png redimensionada a (80, 80).
# Imagen 60.png redimensionada a (80, 80).
# Imagen 61.png redimensionada a (80, 80).
# Imagen 62.png redimensionada a (80, 80).
# Imagen 63.png redimensionada a (80, 80).
# Imagen 64.png redimensionada a (80, 80).
# Imagen 65.png redimensionada a (80, 80).
# Imagen 66.png redimensionada a (80, 80).
# Imagen 67.png redimensionada a (80, 80).
# Imagen 68.png redimensionada a (80, 80).
# Imagen 69.png redimensionada a (80, 80).
# Imagen 6edgarsorprendido.png redimensionada a (80, 80).
# Imagen 7.png redimensionada a (80, 80).
# Imagen 70.png redimensionada a (80, 80).
# Imagen 71.png redimensionada a (80, 80).
# Imagen 72.png redimensionada a (80, 80).
# Imagen 73.png redimensionada a (80, 80).
# Imagen 74.png redimensionada a (80, 80).
# Imagen 75.png redimensionada a (80, 80).
# Imagen 76.png redimensionada a (80, 80).
# Imagen 77.png redimensionada a (80, 80).
# Imagen 78.png redimensionada a (80, 80).
# Imagen 79.png redimensionada a (80, 80).
# Imagen 7edgarsorprendido.png redimensionada a (80, 80).
# Imagen 8.png redimensionada a (80, 80).
# Imagen 80.png redimensionada a (80, 80).
# Imagen 81.png redimensionada a (80, 80).
# Imagen 82.png redimensionada a (80, 80).
# Imagen 83.png redimensionada a (80, 80).
# Imagen 84.png redimensionada a (80, 80).
# Imagen 85.png redimensionada a (80, 80).
# Imagen 86.png redimensionada a (80, 80).
# Imagen 87.png redimensionada a (80, 80).
# Imagen 88.png redimensionada a (80, 80).
# Imagen 89.png redimensionada a (80, 80).
# Imagen 8edgarsorprendido.png redimensionada a (80, 80).
# Imagen 9.png redimensionada a (80, 80).
# Imagen 90.png redimensionada a (80, 80).
# Imagen 91.png redimensionada a (80, 80).
# Imagen 92.png redimensionada a (80, 80).
# Imagen 93.png redimensionada a (80, 80).
# Imagen 94.png redimensionada a (80, 80).
# Imagen 95.png redimensionada a (80, 80).
# Imagen 96.png redimensionada a (80, 80).
# Imagen 97.png redimensionada a (80, 80).
# Imagen 98.png redimensionada a (80, 80).
# Imagen 99.png redimensionada a (80, 80).
# Imagen 9edgarsorprendido.png redimensionada a (80, 80).
# Imagen AngelSorprendido0.png redimensionada a (80, 80).
# Imagen AngelSorprendido1.png redimensionada a (80, 80).
# Imagen AngelSorprendido10.png redimensionada a (80, 80).
# Imagen AngelSorprendido11.png redimensionada a (80, 80).
# Imagen AngelSorprendido12.png redimensionada a (80, 80).
# Imagen AngelSorprendido13.png redimensionada a (80, 80).
# Imagen AngelSorprendido14.png redimensionada a (80, 80).
# Imagen AngelSorprendido15.png redimensionada a (80, 80).
# Imagen AngelSorprendido16.png redimensionada a (80, 80).
# Imagen AngelSorprendido169.png redimensionada a (80, 80).
# Imagen AngelSorprendido17.png redimensionada a (80, 80).
# Imagen AngelSorprendido170.png redimensionada a (80, 80).
# Imagen AngelSorprendido171.png redimensionada a (80, 80).
# Imagen AngelSorprendido172.png redimensionada a (80, 80).
# Imagen AngelSorprendido173.png redimensionada a (80, 80).
# Imagen AngelSorprendido174.png redimensionada a (80, 80).
# Imagen AngelSorprendido175.png redimensionada a (80, 80).
# Imagen AngelSorprendido176.png redimensionada a (80, 80).
# Imagen AngelSorprendido177.png redimensionada a (80, 80).
# Imagen AngelSorprendido178.png redimensionada a (80, 80).
# Imagen AngelSorprendido179.png redimensionada a (80, 80).
# Imagen AngelSorprendido18.png redimensionada a (80, 80).
# Imagen AngelSorprendido180.png redimensionada a (80, 80).
# Imagen AngelSorprendido181.png redimensionada a (80, 80).
# Imagen AngelSorprendido182.png redimensionada a (80, 80).
# Imagen AngelSorprendido183.png redimensionada a (80, 80).
# Imagen AngelSorprendido184.png redimensionada a (80, 80).
# Imagen AngelSorprendido185.png redimensionada a (80, 80).
# Imagen AngelSorprendido186.png redimensionada a (80, 80).
# Imagen AngelSorprendido187.png redimensionada a (80, 80).
# Imagen AngelSorprendido188.png redimensionada a (80, 80).
# Imagen AngelSorprendido189.png redimensionada a (80, 80).
# Imagen AngelSorprendido19.png redimensionada a (80, 80).
# Imagen AngelSorprendido190.png redimensionada a (80, 80).
# Imagen AngelSorprendido191.png redimensionada a (80, 80).
# Imagen AngelSorprendido192.png redimensionada a (80, 80).
# Imagen AngelSorprendido193.png redimensionada a (80, 80).
# Imagen AngelSorprendido194.png redimensionada a (80, 80).
# Imagen AngelSorprendido195.png redimensionada a (80, 80).
# Imagen AngelSorprendido2.png redimensionada a (80, 80).
# Imagen AngelSorprendido20.png redimensionada a (80, 80).
# Imagen AngelSorprendido21.png redimensionada a (80, 80).
# Imagen AngelSorprendido22.png redimensionada a (80, 80).
# Imagen AngelSorprendido23.png redimensionada a (80, 80).
# Imagen AngelSorprendido24.png redimensionada a (80, 80).
# Imagen AngelSorprendido25.png redimensionada a (80, 80).
# Imagen AngelSorprendido26.png redimensionada a (80, 80).
# Imagen AngelSorprendido27.png redimensionada a (80, 80).
# Imagen AngelSorprendido3.png redimensionada a (80, 80).
# Imagen AngelSorprendido4.png redimensionada a (80, 80).
# Imagen AngelSorprendido5.png redimensionada a (80, 80).
# Imagen AngelSorprendido6.png redimensionada a (80, 80).
# Imagen AngelSorprendido7.png redimensionada a (80, 80).
# Imagen AngelSorprendido77.png redimensionada a (80, 80).
# Imagen AngelSorprendido78.png redimensionada a (80, 80).
# Imagen AngelSorprendido79.png redimensionada a (80, 80).
# Imagen AngelSorprendido8.png redimensionada a (80, 80).
# Imagen AngelSorprendido80.png redimensionada a (80, 80).
# Imagen AngelSorprendido81.png redimensionada a (80, 80).
# Imagen AngelSorprendido82.png redimensionada a (80, 80).
# Imagen AngelSorprendido83.png redimensionada a (80, 80).
# Imagen AngelSorprendido84.png redimensionada a (80, 80).
# Imagen AngelSorprendido85.png redimensionada a (80, 80).
# Imagen AngelSorprendido86.png redimensionada a (80, 80).
# Imagen AngelSorprendido87.png redimensionada a (80, 80).
# Imagen AngelSorprendido88.png redimensionada a (80, 80).
# Imagen AngelSorprendido89.png redimensionada a (80, 80).
# Imagen AngelSorprendido9.png redimensionada a (80, 80).
# Imagen AngelSorprendido90.png redimensionada a (80, 80).
# Imagen AngelSorprendido91.png redimensionada a (80, 80).
# Imagen AngelSorprendido92.png redimensionada a (80, 80).
# Imagen AngelSorprendido93.png redimensionada a (80, 80).
# Imagen AngelSorprendido94.png redimensionada a (80, 80).
# Imagen AngelSorprendido95.png redimensionada a (80, 80).
# Imagen AngelSorprendido96.png redimensionada a (80, 80).
# Imagen AngelSorprendido97.png redimensionada a (80, 80).
# Imagen DancySorprendido10.png redimensionada a (80, 80).
# Imagen DancySorprendido11.png redimensionada a (80, 80).
# Imagen DancySorprendido12.png redimensionada a (80, 80).
# Imagen DancySorprendido13.png redimensionada a (80, 80).
# Imagen DancySorprendido14.png redimensionada a (80, 80).
# Imagen DancySorprendido15.png redimensionada a (80, 80).
# Imagen DancySorprendido1574.png redimensionada a (80, 80).
# Imagen DancySorprendido1575.png redimensionada a (80, 80).
# Imagen DancySorprendido1576.png redimensionada a (80, 80).
# Imagen DancySorprendido1577.png redimensionada a (80, 80).
# Imagen DancySorprendido1584.png redimensionada a (80, 80).
# Imagen DancySorprendido1585.png redimensionada a (80, 80).
# Imagen DancySorprendido1586.png redimensionada a (80, 80).
# Imagen DancySorprendido1587.png redimensionada a (80, 80).
# Imagen DancySorprendido1590.png redimensionada a (80, 80).
# Imagen DancySorprendido1591.png redimensionada a (80, 80).
# Imagen DancySorprendido1592.png redimensionada a (80, 80).
# Imagen DancySorprendido1593.png redimensionada a (80, 80).
# Imagen DancySorprendido1594.png redimensionada a (80, 80).
# Imagen DancySorprendido1595.png redimensionada a (80, 80).
# Imagen DancySorprendido1596.png redimensionada a (80, 80).
# Imagen DancySorprendido1597.png redimensionada a (80, 80).
# Imagen DancySorprendido1598.png redimensionada a (80, 80).
# Imagen DancySorprendido16.png redimensionada a (80, 80).
# Imagen DancySorprendido1603.png redimensionada a (80, 80).
# Imagen DancySorprendido1604.png redimensionada a (80, 80).
# Imagen DancySorprendido1605.png redimensionada a (80, 80).
# Imagen DancySorprendido1606.png redimensionada a (80, 80).
# Imagen DancySorprendido17.png redimensionada a (80, 80).
# Imagen DancySorprendido18.png redimensionada a (80, 80).
# Imagen DancySorprendido19.png redimensionada a (80, 80).
# Imagen DancySorprendido2.png redimensionada a (80, 80).
# Imagen DancySorprendido20.png redimensionada a (80, 80).
# Imagen DancySorprendido21.png redimensionada a (80, 80).
# Imagen DancySorprendido3.png redimensionada a (80, 80).
# Imagen DancySorprendido365.png redimensionada a (80, 80).
# Imagen DancySorprendido366.png redimensionada a (80, 80).
# Imagen DancySorprendido367.png redimensionada a (80, 80).
# Imagen DancySorprendido368.png redimensionada a (80, 80).
# Imagen DancySorprendido369.png redimensionada a (80, 80).
# Imagen DancySorprendido370.png redimensionada a (80, 80).
# Imagen DancySorprendido371.png redimensionada a (80, 80).
# Imagen DancySorprendido375.png redimensionada a (80, 80).
# Imagen DancySorprendido376.png redimensionada a (80, 80).
# Imagen DancySorprendido377.png redimensionada a (80, 80).
# Imagen DancySorprendido378.png redimensionada a (80, 80).
# Imagen DancySorprendido379.png redimensionada a (80, 80).
# Imagen DancySorprendido380.png redimensionada a (80, 80).
# Imagen DancySorprendido382.png redimensionada a (80, 80).
# Imagen DancySorprendido383.png redimensionada a (80, 80).
# Imagen DancySorprendido4.png redimensionada a (80, 80).
# Imagen DancySorprendido4067.png redimensionada a (80, 80).
# Imagen DancySorprendido4068.png redimensionada a (80, 80).
# Imagen DancySorprendido4069.png redimensionada a (80, 80).
# Imagen DancySorprendido4070.png redimensionada a (80, 80).
# Imagen DancySorprendido4072.png redimensionada a (80, 80).
# Imagen DancySorprendido4073.png redimensionada a (80, 80).
# Imagen DancySorprendido4074.png redimensionada a (80, 80).
# Imagen DancySorprendido4075.png redimensionada a (80, 80).
# Imagen DancySorprendido4076.png redimensionada a (80, 80).
# Imagen DancySorprendido4077.png redimensionada a (80, 80).
# Imagen DancySorprendido4080.png redimensionada a (80, 80).
# Imagen DancySorprendido4081.png redimensionada a (80, 80).
# Imagen DancySorprendido4082.png redimensionada a (80, 80).
# Imagen DancySorprendido4083.png redimensionada a (80, 80).
# Imagen DancySorprendido4084.png redimensionada a (80, 80).
# Imagen DancySorprendido4085.png redimensionada a (80, 80).
# Imagen DancySorprendido4086.png redimensionada a (80, 80).
# Imagen DancySorprendido4087.png redimensionada a (80, 80).
# Imagen DancySorprendido4088.png redimensionada a (80, 80).
# Imagen DancySorprendido4089.png redimensionada a (80, 80).
# Imagen DancySorprendido4090.png redimensionada a (80, 80).
# Imagen DancySorprendido4091.png redimensionada a (80, 80).
# Imagen DancySorprendido4092.png redimensionada a (80, 80).
# Imagen DancySorprendido4093.png redimensionada a (80, 80).
# Imagen DancySorprendido411.png redimensionada a (80, 80).
# Imagen DancySorprendido412.png redimensionada a (80, 80).
# Imagen DancySorprendido413.png redimensionada a (80, 80).
# Imagen DancySorprendido414.png redimensionada a (80, 80).
# Imagen DancySorprendido415.png redimensionada a (80, 80).
# Imagen DancySorprendido416.png redimensionada a (80, 80).
# Imagen DancySorprendido417.png redimensionada a (80, 80).
# Imagen DancySorprendido418.png redimensionada a (80, 80).
# Imagen DancySorprendido4292.png redimensionada a (80, 80).
# Imagen DancySorprendido4293.png redimensionada a (80, 80).
# Imagen DancySorprendido4294.png redimensionada a (80, 80).
# Imagen DancySorprendido4295.png redimensionada a (80, 80).
# Imagen DancySorprendido4296.png redimensionada a (80, 80).
# Imagen DancySorprendido4297.png redimensionada a (80, 80).
# Imagen DancySorprendido4298.png redimensionada a (80, 80).
# Imagen DancySorprendido4299.png redimensionada a (80, 80).
# Imagen DancySorprendido4300.png redimensionada a (80, 80).
# Imagen DancySorprendido4301.png redimensionada a (80, 80).
# Imagen DancySorprendido4302.png redimensionada a (80, 80).
# Imagen DancySorprendido4303.png redimensionada a (80, 80).
# Imagen DancySorprendido4304.png redimensionada a (80, 80).
# Imagen DancySorprendido4305.png redimensionada a (80, 80).
# Imagen DancySorprendido4306.png redimensionada a (80, 80).
# Imagen DancySorprendido4307.png redimensionada a (80, 80).
# Imagen DancySorprendido4308.png redimensionada a (80, 80).
# Imagen DancySorprendido4309.png redimensionada a (80, 80).
# Imagen DancySorprendido4310.png redimensionada a (80, 80).
# Imagen DancySorprendido4343.png redimensionada a (80, 80).
# Imagen DancySorprendido4344.png redimensionada a (80, 80).
# Imagen DancySorprendido4362.png redimensionada a (80, 80).
# Imagen DancySorprendido4363.png redimensionada a (80, 80).
# Imagen DancySorprendido4364.png redimensionada a (80, 80).
# Imagen DancySorprendido4365.png redimensionada a (80, 80).
# Imagen DancySorprendido4434.png redimensionada a (80, 80).
# Imagen DancySorprendido4435.png redimensionada a (80, 80).
# Imagen DancySorprendido4438.png redimensionada a (80, 80).
# Imagen DancySorprendido4439.png redimensionada a (80, 80).
# Imagen DancySorprendido4527.png redimensionada a (80, 80).
# Imagen DancySorprendido4528.png redimensionada a (80, 80).
# Imagen DancySorprendido4529.png redimensionada a (80, 80).
# Imagen DancySorprendido4530.png redimensionada a (80, 80).
# Imagen DancySorprendido4531.png redimensionada a (80, 80).
# Imagen DancySorprendido4532.png redimensionada a (80, 80).
# Imagen DancySorprendido4533.png redimensionada a (80, 80).
# Imagen DancySorprendido4534.png redimensionada a (80, 80).
# Imagen DancySorprendido4535.png redimensionada a (80, 80).
# Imagen DancySorprendido4536.png redimensionada a (80, 80).
# Imagen DancySorprendido4537.png redimensionada a (80, 80).
# Imagen DancySorprendido4538.png redimensionada a (80, 80).
# Imagen DancySorprendido4539.png redimensionada a (80, 80).
# Imagen DancySorprendido4540.png redimensionada a (80, 80).
# Imagen DancySorprendido4541.png redimensionada a (80, 80).
# Imagen DancySorprendido4542.png redimensionada a (80, 80).
# Imagen DancySorprendido4543.png redimensionada a (80, 80).
# Imagen DancySorprendido4544.png redimensionada a (80, 80).
# Imagen DancySorprendido4548.png redimensionada a (80, 80).
# Imagen DancySorprendido4549.png redimensionada a (80, 80).
# Imagen DancySorprendido4550.png redimensionada a (80, 80).
# Imagen DancySorprendido4596.png redimensionada a (80, 80).
# Imagen DancySorprendido4597.png redimensionada a (80, 80).
# Imagen DancySorprendido4598.png redimensionada a (80, 80).
# Imagen DancySorprendido4605.png redimensionada a (80, 80).
# Imagen DancySorprendido4606.png redimensionada a (80, 80).
# Imagen DancySorprendido4607.png redimensionada a (80, 80).
# Imagen DancySorprendido4611.png redimensionada a (80, 80).
# Imagen DancySorprendido4612.png redimensionada a (80, 80).
# Imagen DancySorprendido4613.png redimensionada a (80, 80).
# Imagen DancySorprendido4620.png redimensionada a (80, 80).
# Imagen DancySorprendido4621.png redimensionada a (80, 80).
# Imagen DancySorprendido4622.png redimensionada a (80, 80).
# Imagen DancySorprendido5.png redimensionada a (80, 80).
# Imagen DancySorprendido6.png redimensionada a (80, 80).
# Imagen DancySorprendido910.png redimensionada a (80, 80).
# Imagen DancySorprendido911.png redimensionada a (80, 80).
# Imagen DancySorprendido912.png redimensionada a (80, 80).
# Imagen DancySorprendido913.png redimensionada a (80, 80).
# Imagen DancySorprendido914.png redimensionada a (80, 80).
# Imagen DancySorprendido915.png redimensionada a (80, 80).
# Imagen DancySorprendido916.png redimensionada a (80, 80).
# Imagen DancySorprendido917.png redimensionada a (80, 80).
# Imagen DancySorprendido918.png redimensionada a (80, 80).
# Imagen DancySorprendido919.png redimensionada a (80, 80).
# Imagen DancySorprendido920.png redimensionada a (80, 80).
# Imagen DancySorprendido921.png redimensionada a (80, 80).
# Imagen DancySorprendido922.png redimensionada a (80, 80).
# Imagen DancySorprendido924.png redimensionada a (80, 80).
# Imagen DancySorprendido925.png redimensionada a (80, 80).
# Imagen DancySorprendido926.png redimensionada a (80, 80).
# Imagen DancySorprendido927.png redimensionada a (80, 80).
# Imagen DancySorprendido928.png redimensionada a (80, 80).
# Imagen DancySorprendido929.png redimensionada a (80, 80).
# Imagen DancySorprendido930.png redimensionada a (80, 80).
# Imagen DancySorprendido931.png redimensionada a (80, 80).
# Imagen Fe109.png redimensionada a (80, 80).
# Imagen Fe110.png redimensionada a (80, 80).
# Imagen Fe111.png redimensionada a (80, 80).
# Imagen Fe113.png redimensionada a (80, 80).
# Imagen Fe114.png redimensionada a (80, 80).
# Imagen Fe115.png redimensionada a (80, 80).
# Imagen Fe116.png redimensionada a (80, 80).
# Imagen Fe117.png redimensionada a (80, 80).
# Imagen Fe126.png redimensionada a (80, 80).
# Imagen Fe127.png redimensionada a (80, 80).
# Imagen Fe128.png redimensionada a (80, 80).
# Imagen Fe129.png redimensionada a (80, 80).
# Imagen Fe130.png redimensionada a (80, 80).
# Imagen Fe131.png redimensionada a (80, 80).
# Imagen Fe134.png redimensionada a (80, 80).
# Imagen Fe135.png redimensionada a (80, 80).
# Imagen Fe137.png redimensionada a (80, 80).
# Imagen Fe138.png redimensionada a (80, 80).
# Imagen Fe139.png redimensionada a (80, 80).
# Imagen Fe141.png redimensionada a (80, 80).
# Imagen Fe142.png redimensionada a (80, 80).
# Imagen Fe147.png redimensionada a (80, 80).
# Imagen Fe148.png redimensionada a (80, 80).
# Imagen Fe154.png redimensionada a (80, 80).
# Imagen Fe155.png redimensionada a (80, 80).
# Imagen Fe156.png redimensionada a (80, 80).
# Imagen Fe157.png redimensionada a (80, 80).
# Imagen Fe174.png redimensionada a (80, 80).
# Imagen Fe175.png redimensionada a (80, 80).
# Imagen Fe176.png redimensionada a (80, 80).
# Imagen Fe177.png redimensionada a (80, 80).
# Imagen Fe178.png redimensionada a (80, 80).
# Imagen Fe179.png redimensionada a (80, 80).
# Imagen Fe180.png redimensionada a (80, 80).
# Imagen Fe184.png redimensionada a (80, 80).
# Imagen Fe185.png redimensionada a (80, 80).
# Imagen Fe20.png redimensionada a (80, 80).
# Imagen Fe21.png redimensionada a (80, 80).
# Imagen Fe22.png redimensionada a (80, 80).
# Imagen Fe23.png redimensionada a (80, 80).
# Imagen Fe24.png redimensionada a (80, 80).
# Imagen Fe25.png redimensionada a (80, 80).
# Imagen Fe26.png redimensionada a (80, 80).
# Imagen Fe27.png redimensionada a (80, 80).
# Imagen Fe28.png redimensionada a (80, 80).
# Imagen Fe29.png redimensionada a (80, 80).
# Imagen Fe30.png redimensionada a (80, 80).
# Imagen Fe31.png redimensionada a (80, 80).
# Imagen Fe32.png redimensionada a (80, 80).
# Imagen Fe33.png redimensionada a (80, 80).
# Imagen Fe34.png redimensionada a (80, 80).
# Imagen Fe35.png redimensionada a (80, 80).
# Imagen Fe36.png redimensionada a (80, 80).
# Imagen Fe37.png redimensionada a (80, 80).
# Imagen Fe38.png redimensionada a (80, 80).
# Imagen Fe39.png redimensionada a (80, 80).
# Imagen Fe40.png redimensionada a (80, 80).
# Imagen Fe41.png redimensionada a (80, 80).
# Imagen Fe42.png redimensionada a (80, 80).
# Imagen Fe43.png redimensionada a (80, 80).
# Imagen Fe44.png redimensionada a (80, 80).
# Imagen Fe45.png redimensionada a (80, 80).
# Imagen Fe46.png redimensionada a (80, 80).
# Imagen Fe47.png redimensionada a (80, 80).
# Imagen Fe48.png redimensionada a (80, 80).
# Imagen Fe49.png redimensionada a (80, 80).
# Imagen Fe50.png redimensionada a (80, 80).
# Imagen Fe51.png redimensionada a (80, 80).
# Imagen Fe52.png redimensionada a (80, 80).
# Imagen Fe53.png redimensionada a (80, 80).
# Imagen Fe54.png redimensionada a (80, 80).
# Imagen Fe55.png redimensionada a (80, 80).
# Imagen Fe56.png redimensionada a (80, 80).
# Imagen Fe57.png redimensionada a (80, 80).
# Imagen Fe58.png redimensionada a (80, 80).
# Imagen Fe59.png redimensionada a (80, 80).
# Imagen Fe60.png redimensionada a (80, 80).
# Imagen Fe61.png redimensionada a (80, 80).
# Imagen Fe62.png redimensionada a (80, 80).
# Imagen Fe63.png redimensionada a (80, 80).
# Imagen Fe64.png redimensionada a (80, 80).
# Imagen Fe65.png redimensionada a (80, 80).
# Imagen Fe66.png redimensionada a (80, 80).
# Imagen Fe68.png redimensionada a (80, 80).
# Imagen Fe69.png redimensionada a (80, 80).
# Imagen Fe70.png redimensionada a (80, 80).
# Imagen Fe71.png redimensionada a (80, 80).
# Imagen Fe72.png redimensionada a (80, 80).
# Imagen Fe73.png redimensionada a (80, 80).
# Imagen Fe74.png redimensionada a (80, 80).
# Imagen Fe75.png redimensionada a (80, 80).
# Imagen Fe76.png redimensionada a (80, 80).
# Imagen Fe77.png redimensionada a (80, 80).
# Imagen Fe78.png redimensionada a (80, 80).
# Imagen Fe79.png redimensionada a (80, 80).
# Imagen Fe80.png redimensionada a (80, 80).
# Imagen Fe81.png redimensionada a (80, 80).
# Imagen Fe82.png redimensionada a (80, 80).
# Imagen Fe83.png redimensionada a (80, 80).
# Imagen Fe84.png redimensionada a (80, 80).
# Imagen Fe85.png redimensionada a (80, 80).
# Imagen Fe86.png redimensionada a (80, 80).
# Imagen Fe87.png redimensionada a (80, 80).
# Imagen Fe88.png redimensionada a (80, 80).
# Imagen Fe89.png redimensionada a (80, 80).
# Imagen Fe90.png redimensionada a (80, 80).
# Imagen Fe91.png redimensionada a (80, 80).
# Imagen Fe92.png redimensionada a (80, 80).
# Imagen Fe93.png redimensionada a (80, 80).
# Imagen Fe94.png redimensionada a (80, 80).
# Imagen Fe95.png redimensionada a (80, 80).
# Imagen Fel100.png redimensionada a (80, 80).
# Imagen Fel101.png redimensionada a (80, 80).
# Imagen Fel102.png redimensionada a (80, 80).
# Imagen Fel103.png redimensionada a (80, 80).
# Imagen Fel104.png redimensionada a (80, 80).
# Imagen Fel105.png redimensionada a (80, 80).
# Imagen Fel106.png redimensionada a (80, 80).
# Imagen Fel107.png redimensionada a (80, 80).
# Imagen Fel108.png redimensionada a (80, 80).
# Imagen Fel109.png redimensionada a (80, 80).
# Imagen Fel110.png redimensionada a (80, 80).
# Imagen Fel111.png redimensionada a (80, 80).
# Imagen Fel112.png redimensionada a (80, 80).
# Imagen Fel113.png redimensionada a (80, 80).
# Imagen Fel114.png redimensionada a (80, 80).
# Imagen Fel115.png redimensionada a (80, 80).
# Imagen Fel116.png redimensionada a (80, 80).
# Imagen Fel117.png redimensionada a (80, 80).
# Imagen Fel118.png redimensionada a (80, 80).
# Imagen Fel119.png redimensionada a (80, 80).
# Imagen Fel120.png redimensionada a (80, 80).
# Imagen Fel121.png redimensionada a (80, 80).
# Imagen Fel122.png redimensionada a (80, 80).
# Imagen Fel123.png redimensionada a (80, 80).
# Imagen Fel144.png redimensionada a (80, 80).
# Imagen Fel145.png redimensionada a (80, 80).
# Imagen Fel146.png redimensionada a (80, 80).
# Imagen Fel147.png redimensionada a (80, 80).
# Imagen Fel148.png redimensionada a (80, 80).
# Imagen Fel149.png redimensionada a (80, 80).
# Imagen Fel150.png redimensionada a (80, 80).
# Imagen Fel151.png redimensionada a (80, 80).
# Imagen Fel152.png redimensionada a (80, 80).
# Imagen Fel153.png redimensionada a (80, 80).
# Imagen Fel154.png redimensionada a (80, 80).
# Imagen Fel155.png redimensionada a (80, 80).
# Imagen Fel156.png redimensionada a (80, 80).
# Imagen Fel157.png redimensionada a (80, 80).
# Imagen Fel158.png redimensionada a (80, 80).
# Imagen Fel159.png redimensionada a (80, 80).
# Imagen Fel160.png redimensionada a (80, 80).
# Imagen Fel161.png redimensionada a (80, 80).
# Imagen Fel162.png redimensionada a (80, 80).
# Imagen Fel163.png redimensionada a (80, 80).
# Imagen Fel164.png redimensionada a (80, 80).
# Imagen Fel165.png redimensionada a (80, 80).
# Imagen Fel166.png redimensionada a (80, 80).
# Imagen Fel167.png redimensionada a (80, 80).
# Imagen Fel168.png redimensionada a (80, 80).
# Imagen Fel169.png redimensionada a (80, 80).
# Imagen Fel170.png redimensionada a (80, 80).
# Imagen Fel171.png redimensionada a (80, 80).
# Imagen Fel215.png redimensionada a (80, 80).
# Imagen Fel216.png redimensionada a (80, 80).
# Imagen Fel217.png redimensionada a (80, 80).
# Imagen Fel218.png redimensionada a (80, 80).
# Imagen Fel26.png redimensionada a (80, 80).
# Imagen Fel27.png redimensionada a (80, 80).
# Imagen Fel28.png redimensionada a (80, 80).
# Imagen Fel29.png redimensionada a (80, 80).
# Imagen Fel30.png redimensionada a (80, 80).
# Imagen Fel31.png redimensionada a (80, 80).
# Imagen Fel32.png redimensionada a (80, 80).
# Imagen Fel33.png redimensionada a (80, 80).
# Imagen Fel34.png redimensionada a (80, 80).
# Imagen Fel35.png redimensionada a (80, 80).
# Imagen Fel4.png redimensionada a (80, 80).
# Imagen Fel46.png redimensionada a (80, 80).
# Imagen Fel47.png redimensionada a (80, 80).
# Imagen Fel48.png redimensionada a (80, 80).
# Imagen Fel49.png redimensionada a (80, 80).
# Imagen Fel5.png redimensionada a (80, 80).
# Imagen Fel50.png redimensionada a (80, 80).
# Imagen Fel51.png redimensionada a (80, 80).
# Imagen Fel56.png redimensionada a (80, 80).
# Imagen Fel57.png redimensionada a (80, 80).
# Imagen Fel58.png redimensionada a (80, 80).
# Imagen Fel59.png redimensionada a (80, 80).
# Imagen Fel6.png redimensionada a (80, 80).
# Imagen Fel7.png redimensionada a (80, 80).
# Imagen Fel8.png redimensionada a (80, 80).
# Imagen Fel87.png redimensionada a (80, 80).
# Imagen Fel88.png redimensionada a (80, 80).
# Imagen Fel89.png redimensionada a (80, 80).
# Imagen Fel90.png redimensionada a (80, 80).
# Imagen Fel91.png redimensionada a (80, 80).
# Imagen Fel92.png redimensionada a (80, 80).
# Imagen Fel93.png redimensionada a (80, 80).
# Imagen Fel94.png redimensionada a (80, 80).
# Imagen Fel95.png redimensionada a (80, 80).
# Imagen Fel96.png redimensionada a (80, 80).
# Imagen Fel97.png redimensionada a (80, 80).
# Imagen Fel98.png redimensionada a (80, 80).
# Imagen Fel99.png redimensionada a (80, 80).
# Imagen jonhySorpr134.png redimensionada a (80, 80).
# Imagen jonhySorpr138.png redimensionada a (80, 80).
# Imagen jonhySorpr139.png redimensionada a (80, 80).
# Imagen jonhySorpr140.png redimensionada a (80, 80).
# Imagen jonhySorpr141.png redimensionada a (80, 80).
# Imagen jonhySorpr142.png redimensionada a (80, 80).
# Imagen jonhySorpr143.png redimensionada a (80, 80).
# Imagen jonhySorpr144.png redimensionada a (80, 80).
# Imagen jonhySorpr145.png redimensionada a (80, 80).
# Imagen jonhySorpr146.png redimensionada a (80, 80).
# Imagen jonhySorpr147.png redimensionada a (80, 80).
# Imagen jonhySorpr148.png redimensionada a (80, 80).
# Imagen jonhySorpr149.png redimensionada a (80, 80).
# Imagen jonhySorpr150.png redimensionada a (80, 80).
# Imagen jonhySorpr152.png redimensionada a (80, 80).
# Imagen jonhySorpr153.png redimensionada a (80, 80).
# Imagen jonhySorpr168.png redimensionada a (80, 80).
# Imagen jonhySorpr172.png redimensionada a (80, 80).
# Imagen jonhySorpr173.png redimensionada a (80, 80).
# Imagen jonhySorpr174.png redimensionada a (80, 80).
# Imagen jonhySorpr175.png redimensionada a (80, 80).
# Imagen jonhySorpr176.png redimensionada a (80, 80).
# Imagen jonhySorpr181.png redimensionada a (80, 80).
# Imagen jonhySorpr209.png redimensionada a (80, 80).
# Imagen jonhySorpr210.png redimensionada a (80, 80).
# Imagen jonhySorpr211.png redimensionada a (80, 80).
# Imagen jonhySorpr212.png redimensionada a (80, 80).
# Imagen jonhySorpr214.png redimensionada a (80, 80).
# Imagen jonhySorpr215.png redimensionada a (80, 80).
# Imagen jonhySorpr263.png redimensionada a (80, 80).
# Imagen jonhySorpr264.png redimensionada a (80, 80).
# Imagen jonhySorpr265.png redimensionada a (80, 80).
# Imagen jonhySorpr266.png redimensionada a (80, 80).
# Imagen jonhySorpr267.png redimensionada a (80, 80).
# Imagen jonhySorpr268.png redimensionada a (80, 80).
# Imagen jonhySorpr269.png redimensionada a (80, 80).
# Imagen jonhySorpr270.png redimensionada a (80, 80).
# Imagen jonhySorpr271.png redimensionada a (80, 80).
# Imagen jonhySorpr272.png redimensionada a (80, 80).
# Imagen jonhySorpr273.png redimensionada a (80, 80).
# Imagen jonhySorpr274.png redimensionada a (80, 80).
# Imagen jonhySorpr275.png redimensionada a (80, 80).
# Imagen jonhySorpr276.png redimensionada a (80, 80).
# Imagen jonhySorpr277.png redimensionada a (80, 80).
# Imagen jonhySorpr278.png redimensionada a (80, 80).
# Imagen jonhySorpr279.png redimensionada a (80, 80).
# Imagen jonhySorpr280.png redimensionada a (80, 80).
# Imagen jonhySorpr281.png redimensionada a (80, 80).
# Imagen jonhySorpr282.png redimensionada a (80, 80).
# Imagen jonhySorpr283.png redimensionada a (80, 80).
# Imagen jonhySorpr287.png redimensionada a (80, 80).
# Imagen jonhySorpr288.png redimensionada a (80, 80).
# Imagen jonhySorpr289.png redimensionada a (80, 80).
# Imagen jonhySorpr290.png redimensionada a (80, 80).
# Imagen jonhySorpr386.png redimensionada a (80, 80).
# Imagen jonhySorpr387.png redimensionada a (80, 80).
# Imagen jonhySorpr388.png redimensionada a (80, 80).
# Imagen jonhySorpr389.png redimensionada a (80, 80).
# Imagen jonhySorpr390.png redimensionada a (80, 80).
# Imagen jonhySorpr391.png redimensionada a (80, 80).
# Imagen jonhySorpr392.png redimensionada a (80, 80).
# Imagen jonhySorpr393.png redimensionada a (80, 80).
# Imagen jonhySorpr554.png redimensionada a (80, 80).
# Imagen jonhySorpr555.png redimensionada a (80, 80).
# Imagen jonhySorpr556.png redimensionada a (80, 80).
# Imagen jonhySorpr557.png redimensionada a (80, 80).
# Imagen jonhySorpr558.png redimensionada a (80, 80).
# Imagen jonhySorpr559.png redimensionada a (80, 80).
# Imagen jonhySorpr560.png redimensionada a (80, 80).
# Imagen jonhySorpr561.png redimensionada a (80, 80).
# Imagen jonhySorpr562.png redimensionada a (80, 80).
# Imagen jonhySorpr563.png redimensionada a (80, 80).
# Imagen jonhySorpr564.png redimensionada a (80, 80).
# Imagen jonhySorpr565.png redimensionada a (80, 80).
# Imagen jonhySorpr566.png redimensionada a (80, 80).
# Imagen jonhySorpr567.png redimensionada a (80, 80).
# Imagen jonhySorpr568.png redimensionada a (80, 80).
# Imagen jonhySorpr589.png redimensionada a (80, 80).
# Imagen jonhySorpr591.png redimensionada a (80, 80).
# Imagen jonhySorpr592.png redimensionada a (80, 80).
# Imagen jonhySorpr593.png redimensionada a (80, 80).
# Imagen jonhySorpr594.png redimensionada a (80, 80).
# Imagen jonhySorpr595.png redimensionada a (80, 80).
# Imagen LeoSorprendido337.png redimensionada a (80, 80).
# Imagen LeoSorprendido338.png redimensionada a (80, 80).
# Imagen LeoSorprendido339.png redimensionada a (80, 80).
# Imagen LeoSorprendido340.png redimensionada a (80, 80).
# Imagen LeoSorprendido341.png redimensionada a (80, 80).
# Imagen LeoSorprendido342.png redimensionada a (80, 80).
# Imagen LeoSorprendido343.png redimensionada a (80, 80).
# Imagen LeoSorprendido344.png redimensionada a (80, 80).
# Imagen LeoSorprendido345.png redimensionada a (80, 80).
# Imagen LeoSorprendido346.png redimensionada a (80, 80).
# Imagen LeoSorprendido347.png redimensionada a (80, 80).
# Imagen LeoSorprendido348.png redimensionada a (80, 80).
# Imagen LeoSorprendido349.png redimensionada a (80, 80).
# Imagen LeoSorprendido350.png redimensionada a (80, 80).
# Imagen LeoSorprendido351.png redimensionada a (80, 80).
# Imagen LeoSorprendido352.png redimensionada a (80, 80).
# Imagen LeoSorprendido353.png redimensionada a (80, 80).
# Imagen LeoSorprendido354.png redimensionada a (80, 80).
# Imagen LeoSorprendido355.png redimensionada a (80, 80).
# Imagen LeoSorprendido356.png redimensionada a (80, 80).
# Imagen LeoSorprendido357.png redimensionada a (80, 80).
# Imagen LeoSorprendido495.png redimensionada a (80, 80).
# Imagen LeoSorprendido496.png redimensionada a (80, 80).
# Imagen LeoSorprendido497.png redimensionada a (80, 80).
# Imagen LeoSorprendido498.png redimensionada a (80, 80).
# Imagen LeoSorprendido499.png redimensionada a (80, 80).
# Imagen LeoSorprendido500.png redimensionada a (80, 80).
# Imagen LeoSorprendido501.png redimensionada a (80, 80).
# Imagen LeoSorprendido502.png redimensionada a (80, 80).
# Imagen LeoSorprendido503.png redimensionada a (80, 80).
# Imagen LeoSorprendido504.png redimensionada a (80, 80).
# Imagen LeoSorprendido506.png redimensionada a (80, 80).
# Imagen LeoSorprendido507.png redimensionada a (80, 80).
# Imagen LeoSorprendido508.png redimensionada a (80, 80).
# Imagen LeoSorprendido509.png redimensionada a (80, 80).
# Imagen LeoSorprendido510.png redimensionada a (80, 80).
# Imagen LeoSorprendido511.png redimensionada a (80, 80).
# Imagen LeoSorprendido512.png redimensionada a (80, 80).
# Imagen LeoSorprendido513.png redimensionada a (80, 80).
# Imagen LeoSorprendido666.png redimensionada a (80, 80).
# Imagen LeoSorprendido667.png redimensionada a (80, 80).
# Imagen LeoSorprendido668.png redimensionada a (80, 80).
# Imagen LeoSorprendido669.png redimensionada a (80, 80).
# Imagen LeoSorprendido670.png redimensionada a (80, 80).
# Imagen LeoSorprendido671.png redimensionada a (80, 80).
# Imagen LeoSorprendido672.png redimensionada a (80, 80).
# Imagen LeoSorprendido673.png redimensionada a (80, 80).
# Imagen LeoSorprendido674.png redimensionada a (80, 80).
# Imagen LeoSorprendido675.png redimensionada a (80, 80).
# Imagen LeoSorprendido676.png redimensionada a (80, 80).
# Imagen LeoSorprendido677.png redimensionada a (80, 80).
# Imagen LeoSorprendido678.png redimensionada a (80, 80).
# Imagen LeoSorprendido679.png redimensionada a (80, 80).
# Imagen LeoSorprendido680.png redimensionada a (80, 80).
# Imagen moy123.png redimensionada a (80, 80).
# Imagen moy124.png redimensionada a (80, 80).
# Imagen moy125.png redimensionada a (80, 80).
# Imagen moy126.png redimensionada a (80, 80).
# Imagen moy127.png redimensionada a (80, 80).
# Imagen moy128.png redimensionada a (80, 80).
# Imagen moy129.png redimensionada a (80, 80).
# Imagen moy130.png redimensionada a (80, 80).
# Imagen moy131.png redimensionada a (80, 80).
# Imagen moy132.png redimensionada a (80, 80).
# Imagen moy133.png redimensionada a (80, 80).
# Imagen moy134.png redimensionada a (80, 80).
# Imagen moy135.png redimensionada a (80, 80).
# Imagen moy136.png redimensionada a (80, 80).
# Imagen moy137.png redimensionada a (80, 80).
# Imagen moy138.png redimensionada a (80, 80).
# Imagen moy139.png redimensionada a (80, 80).
# Imagen moy140.png redimensionada a (80, 80).
# Imagen moy141.png redimensionada a (80, 80).
# Imagen moy142.png redimensionada a (80, 80).
# Imagen moy143.png redimensionada a (80, 80).
# Imagen moy144.png redimensionada a (80, 80).
# Imagen moy145.png redimensionada a (80, 80).
# Imagen moy146.png redimensionada a (80, 80).
# Imagen moy147.png redimensionada a (80, 80).
# Imagen moy148.png redimensionada a (80, 80).
# Imagen moy149.png redimensionada a (80, 80).
# Imagen moy207.png redimensionada a (80, 80).
# Imagen moy208.png redimensionada a (80, 80).
# Imagen moy209.png redimensionada a (80, 80).
# Imagen moy210.png redimensionada a (80, 80).
# Imagen moy211.png redimensionada a (80, 80).
# Imagen moy212.png redimensionada a (80, 80).
# Imagen moy213.png redimensionada a (80, 80).
# Imagen moy214.png redimensionada a (80, 80).
# Imagen moy215.png redimensionada a (80, 80).
# Imagen moy216.png redimensionada a (80, 80).
# Imagen moy217.png redimensionada a (80, 80).
# Imagen moy218.png redimensionada a (80, 80).
# Imagen moy219.png redimensionada a (80, 80).
# Imagen moy220.png redimensionada a (80, 80).
# Imagen moy221.png redimensionada a (80, 80).
# Imagen moy222.png redimensionada a (80, 80).
# Imagen moy223.png redimensionada a (80, 80).
# Imagen moy224.png redimensionada a (80, 80).
# Imagen moy225.png redimensionada a (80, 80).
# Imagen moy226.png redimensionada a (80, 80).
# Imagen moy227.png redimensionada a (80, 80).
# Imagen moy228.png redimensionada a (80, 80).
# Imagen moy229.png redimensionada a (80, 80).
# Imagen moy230.png redimensionada a (80, 80).
# Imagen moy231.png redimensionada a (80, 80).
# Imagen moy395.png redimensionada a (80, 80).
# Imagen moy396.png redimensionada a (80, 80).
# Imagen moy397.png redimensionada a (80, 80).
# Imagen moy398.png redimensionada a (80, 80).
# Imagen moy399.png redimensionada a (80, 80).
# Imagen moy400.png redimensionada a (80, 80).
# Imagen moy401.png redimensionada a (80, 80).
# Imagen moy402.png redimensionada a (80, 80).
# Imagen moy403.png redimensionada a (80, 80).
# Imagen moy404.png redimensionada a (80, 80).
# Imagen moy405.png redimensionada a (80, 80).
# Imagen moy406.png redimensionada a (80, 80).
# Imagen moy407.png redimensionada a (80, 80).
# Imagen moy408.png redimensionada a (80, 80).
# Imagen moy409.png redimensionada a (80, 80).
# Imagen moy410.png redimensionada a (80, 80).
# Imagen moy411.png redimensionada a (80, 80).
# Imagen moy412.png redimensionada a (80, 80).
# Imagen moy413.png redimensionada a (80, 80).
# Imagen moy414.png redimensionada a (80, 80).
# Imagen moy415.png redimensionada a (80, 80).
# Imagen moy416.png redimensionada a (80, 80).
# Imagen moy417.png redimensionada a (80, 80).
# Imagen moy418.png redimensionada a (80, 80).
# Imagen moy419.png redimensionada a (80, 80).
# Imagen moy420.png redimensionada a (80, 80).
# Imagen moy421.png redimensionada a (80, 80).
# Imagen moy422.png redimensionada a (80, 80).
# Imagen o10_videouno.png redimensionada a (80, 80).
# Imagen o11_videouno.png redimensionada a (80, 80).
# Imagen o12_videouno.png redimensionada a (80, 80).
# Imagen o13_videouno.png redimensionada a (80, 80).
# Imagen o14_videouno.png redimensionada a (80, 80).
# Imagen o15_videouno.png redimensionada a (80, 80).
# Imagen o16_videouno.png redimensionada a (80, 80).
# Imagen o17_videouno.png redimensionada a (80, 80).
# Imagen o18_videouno.png redimensionada a (80, 80).
# Imagen o19_videouno.png redimensionada a (80, 80).
# Imagen o20_videouno.png redimensionada a (80, 80).
# Imagen o21_videouno.png redimensionada a (80, 80).
# Imagen o22_videouno.png redimensionada a (80, 80).
# Imagen o23_videouno.png redimensionada a (80, 80).
# Imagen o24_videouno.png redimensionada a (80, 80).
# Imagen o25_videouno.png redimensionada a (80, 80).
# Imagen o26_videouno.png redimensionada a (80, 80).
# Imagen o27_videouno.png redimensionada a (80, 80).
# Imagen o28_videouno.png redimensionada a (80, 80).
# Imagen o29_videouno.png redimensionada a (80, 80).
# Imagen o30_videouno.png redimensionada a (80, 80).
# Imagen o31_videouno.png redimensionada a (80, 80).
# Imagen o32_videouno.png redimensionada a (80, 80).
# Imagen o33_videouno.png redimensionada a (80, 80).
# Imagen o34_videouno.png redimensionada a (80, 80).
# Imagen o35_videouno.png redimensionada a (80, 80).
# Imagen o36_videouno.png redimensionada a (80, 80).
# Imagen o37_videouno.png redimensionada a (80, 80).
# Imagen o38_videouno.png redimensionada a (80, 80).
# Imagen o39_videouno.png redimensionada a (80, 80).
# Imagen o40_videouno.png redimensionada a (80, 80).
# Imagen o41_videouno.png redimensionada a (80, 80).
# Imagen o42_videouno.png redimensionada a (80, 80).
# Imagen o43_videouno.png redimensionada a (80, 80).
# Imagen o44_videouno.png redimensionada a (80, 80).
# Imagen o45_videouno.png redimensionada a (80, 80).
# Imagen o46_videouno.png redimensionada a (80, 80).
# Imagen o47_videouno.png redimensionada a (80, 80).
# Imagen o48_videouno.png redimensionada a (80, 80).
# Imagen o49_videouno.png redimensionada a (80, 80).
# Imagen o5_videouno.png redimensionada a (80, 80).
# Imagen o6_videouno.png redimensionada a (80, 80).
# Imagen o7_videouno.png redimensionada a (80, 80).
# Imagen o8_videouno.png redimensionada a (80, 80).
# Imagen o9_videouno.png redimensionada a (80, 80).
# ...
# Imagen sorprendidoNetoS90.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS91.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS92.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS93.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS94.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS95.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS96.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS97.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS98.png redimensionada a (80, 80).
# Imagen sorprendidoNetoS99.png redimensionada a (80, 80).
# Imagen sorpresa0esmesi.png redimensionada a (80, 80).
# Imagen sorpresa100esmesi.png redimensionada a (80, 80).
# Imagen sorpresa101esmesi.png redimensionada a (80, 80).
# Imagen sorpresa102esmesi.png redimensionada a (80, 80).
# Imagen sorpresa103esmesi.png redimensionada a (80, 80).
# Imagen sorpresa10esmesi.png redimensionada a (80, 80).
# Imagen sorpresa11esmesi.png redimensionada a (80, 80).
# Imagen sorpresa127esmesi.png redimensionada a (80, 80).
# Imagen sorpresa128esmesi.png redimensionada a (80, 80).
# Imagen sorpresa129esmesi.png redimensionada a (80, 80).
# Imagen sorpresa12esmesi.png redimensionada a (80, 80).
# Imagen sorpresa130esmesi.png redimensionada a (80, 80).
# Imagen sorpresa131esmesi.png redimensionada a (80, 80).
# Imagen sorpresa132esmesi.png redimensionada a (80, 80).
# Imagen sorpresa133esmesi.png redimensionada a (80, 80).
# Imagen sorpresa134esmesi.png redimensionada a (80, 80).
# Imagen sorpresa135esmesi.png redimensionada a (80, 80).
# Imagen sorpresa136esmesi.png redimensionada a (80, 80).
# Imagen sorpresa137esmesi.png redimensionada a (80, 80).
# Imagen sorpresa138esmesi.png redimensionada a (80, 80).
# Imagen sorpresa139esmesi.png redimensionada a (80, 80).
# Imagen sorpresa13esmesi.png redimensionada a (80, 80).
# Imagen sorpresa140esmesi.png redimensionada a (80, 80).
# Imagen sorpresa141esmesi.png redimensionada a (80, 80).
# Imagen sorpresa142esmesi.png redimensionada a (80, 80).
# Imagen sorpresa143esmesi.png redimensionada a (80, 80).
# Imagen sorpresa144esmesi.png redimensionada a (80, 80).
# Imagen sorpresa145esmesi.png redimensionada a (80, 80).
# Imagen sorpresa146esmesi.png redimensionada a (80, 80).
# Imagen sorpresa147esmesi.png redimensionada a (80, 80).
# Imagen sorpresa148esmesi.png redimensionada a (80, 80).
# Imagen sorpresa149esmesi.png redimensionada a (80, 80).
# Imagen sorpresa14esmesi.png redimensionada a (80, 80).
# Imagen sorpresa150esmesi.png redimensionada a (80, 80).
# Imagen sorpresa151esmesi.png redimensionada a (80, 80).
# Imagen sorpresa152esmesi.png redimensionada a (80, 80).
# Imagen sorpresa153esmesi.png redimensionada a (80, 80).
# Imagen sorpresa154esmesi.png redimensionada a (80, 80).
# Imagen sorpresa155esmesi.png redimensionada a (80, 80).
# Imagen sorpresa156esmesi.png redimensionada a (80, 80).
# Imagen sorpresa15esmesi.png redimensionada a (80, 80).
# Imagen sorpresa162esmesi.png redimensionada a (80, 80).
# Imagen sorpresa163esmesi.png redimensionada a (80, 80).
# Imagen sorpresa164esmesi.png redimensionada a (80, 80).
# Imagen sorpresa165esmesi.png redimensionada a (80, 80).
# Imagen sorpresa166esmesi.png redimensionada a (80, 80).
# Imagen sorpresa167esmesi.png redimensionada a (80, 80).
# Imagen sorpresa168esmesi.png redimensionada a (80, 80).
# Imagen sorpresa169esmesi.png redimensionada a (80, 80).
# Imagen sorpresa16esmesi.png redimensionada a (80, 80).
# Imagen sorpresa170esmesi.png redimensionada a (80, 80).
# Imagen sorpresa171esmesi.png redimensionada a (80, 80).
# Imagen sorpresa172esmesi.png redimensionada a (80, 80).
# Imagen sorpresa173esmesi.png redimensionada a (80, 80).
# Imagen sorpresa174esmesi.png redimensionada a (80, 80).
# Imagen sorpresa175esmesi.png redimensionada a (80, 80).
# Imagen sorpresa179esmesi.png redimensionada a (80, 80).
# Imagen sorpresa17esmesi.png redimensionada a (80, 80).
# Imagen sorpresa180esmesi.png redimensionada a (80, 80).
# Imagen sorpresa181esmesi.png redimensionada a (80, 80).
# Imagen sorpresa182esmesi.png redimensionada a (80, 80).
# Imagen sorpresa183esmesi.png redimensionada a (80, 80).
# Imagen sorpresa18esmesi.png redimensionada a (80, 80).
# Imagen sorpresa190esmesi.png redimensionada a (80, 80).
# Imagen sorpresa191esmesi.png redimensionada a (80, 80).
# Imagen sorpresa192esmesi.png redimensionada a (80, 80).
# Imagen sorpresa193esmesi.png redimensionada a (80, 80).
# Imagen sorpresa194esmesi.png redimensionada a (80, 80).
# Imagen sorpresa195esmesi.png redimensionada a (80, 80).
# Imagen sorpresa196esmesi.png redimensionada a (80, 80).
# Imagen sorpresa197esmesi.png redimensionada a (80, 80).
# Imagen sorpresa198esmesi.png redimensionada a (80, 80).
# Imagen sorpresa199esmesi.png redimensionada a (80, 80).
# Imagen sorpresa19esmesi.png redimensionada a (80, 80).
# Imagen sorpresa1esmesi.png redimensionada a (80, 80).
# Imagen sorpresa200esmesi.png redimensionada a (80, 80).
# Imagen sorpresa201esmesi.png redimensionada a (80, 80).
# Imagen sorpresa202esmesi.png redimensionada a (80, 80).
# Imagen sorpresa203esmesi.png redimensionada a (80, 80).
# Imagen sorpresa204esmesi.png redimensionada a (80, 80).
# Imagen sorpresa205esmesi.png redimensionada a (80, 80).
# Imagen sorpresa206esmesi.png redimensionada a (80, 80).
# Imagen sorpresa207esmesi.png redimensionada a (80, 80).
# Imagen sorpresa208esmesi.png redimensionada a (80, 80).
# Imagen sorpresa209esmesi.png redimensionada a (80, 80).
# Imagen sorpresa20esmesi.png redimensionada a (80, 80).
# Imagen sorpresa210esmesi.png redimensionada a (80, 80).
# Imagen sorpresa211esmesi.png redimensionada a (80, 80).
# Imagen sorpresa212esmesi.png redimensionada a (80, 80).
# Imagen sorpresa213esmesi.png redimensionada a (80, 80).
# Imagen sorpresa214esmesi.png redimensionada a (80, 80).
# Imagen sorpresa215esmesi.png redimensionada a (80, 80).
# Imagen sorpresa216esmesi.png redimensionada a (80, 80).
# Imagen sorpresa21esmesi.png redimensionada a (80, 80).
# Imagen sorpresa22esmesi.png redimensionada a (80, 80).
# Imagen sorpresa235esmesi.png redimensionada a (80, 80).
# Imagen sorpresa236esmesi.png redimensionada a (80, 80).
# Imagen sorpresa237esmesi.png redimensionada a (80, 80).
# Imagen sorpresa238esmesi.png redimensionada a (80, 80).
# Imagen sorpresa239esmesi.png redimensionada a (80, 80).
# Imagen sorpresa23esmesi.png redimensionada a (80, 80).
# Imagen sorpresa240esmesi.png redimensionada a (80, 80).
# Imagen sorpresa241esmesi.png redimensionada a (80, 80).
# Imagen sorpresa242esmesi.png redimensionada a (80, 80).
# Imagen sorpresa243esmesi.png redimensionada a (80, 80).
# Imagen sorpresa244esmesi.png redimensionada a (80, 80).
# Imagen sorpresa245esmesi.png redimensionada a (80, 80).
# Imagen sorpresa246esmesi.png redimensionada a (80, 80).
# Imagen sorpresa247esmesi.png redimensionada a (80, 80).
# Imagen sorpresa248esmesi.png redimensionada a (80, 80).
# Imagen sorpresa249esmesi.png redimensionada a (80, 80).
# Imagen sorpresa24esmesi.png redimensionada a (80, 80).
# Imagen sorpresa250esmesi.png redimensionada a (80, 80).
# Imagen sorpresa251esmesi.png redimensionada a (80, 80).
# Imagen sorpresa252esmesi.png redimensionada a (80, 80).
# Imagen sorpresa253esmesi.png redimensionada a (80, 80).
# Imagen sorpresa254esmesi.png redimensionada a (80, 80).
# Imagen sorpresa255esmesi.png redimensionada a (80, 80).
# Imagen sorpresa256esmesi.png redimensionada a (80, 80).
# Imagen sorpresa257esmesi.png redimensionada a (80, 80).
# Imagen sorpresa258esmesi.png redimensionada a (80, 80).
# Imagen sorpresa259esmesi.png redimensionada a (80, 80).
# Imagen sorpresa25esmesi.png redimensionada a (80, 80).
# Imagen sorpresa260esmesi.png redimensionada a (80, 80).
# Imagen sorpresa262esmesi.png redimensionada a (80, 80).
# Imagen sorpresa265esmesi.png redimensionada a (80, 80).
# Imagen sorpresa266esmesi.png redimensionada a (80, 80).
# Imagen sorpresa267esmesi.png redimensionada a (80, 80).
# Imagen sorpresa268esmesi.png redimensionada a (80, 80).
# Imagen sorpresa269esmesi.png redimensionada a (80, 80).
# Imagen sorpresa26esmesi.png redimensionada a (80, 80).
# Imagen sorpresa270esmesi.png redimensionada a (80, 80).
# Imagen sorpresa274esmesi.png redimensionada a (80, 80).
# Imagen sorpresa275esmesi.png redimensionada a (80, 80).
# Imagen sorpresa27esmesi.png redimensionada a (80, 80).
# Imagen sorpresa288esmesi.png redimensionada a (80, 80).
# Imagen sorpresa28esmesi.png redimensionada a (80, 80).
# Imagen sorpresa292esmesi.png redimensionada a (80, 80).
# Imagen sorpresa293esmesi.png redimensionada a (80, 80).
# Imagen sorpresa294esmesi.png redimensionada a (80, 80).
# Imagen sorpresa295esmesi.png redimensionada a (80, 80).
# Imagen sorpresa296esmesi.png redimensionada a (80, 80).
# Imagen sorpresa297esmesi.png redimensionada a (80, 80).
# Imagen sorpresa29esmesi.png redimensionada a (80, 80).
# Imagen sorpresa2esmesi.png redimensionada a (80, 80).
# Imagen sorpresa300esmesi.png redimensionada a (80, 80).
# Imagen sorpresa301esmesi.png redimensionada a (80, 80).
# Imagen sorpresa302esmesi.png redimensionada a (80, 80).
# Imagen sorpresa303esmesi.png redimensionada a (80, 80).
# Imagen sorpresa304esmesi.png redimensionada a (80, 80).
# Imagen sorpresa30esmesi.png redimensionada a (80, 80).
# Imagen sorpresa313esmesi.png redimensionada a (80, 80).
# Imagen sorpresa314esmesi.png redimensionada a (80, 80).
# Imagen sorpresa315esmesi.png redimensionada a (80, 80).
# Imagen sorpresa316esmesi.png redimensionada a (80, 80).
# Imagen sorpresa317esmesi.png redimensionada a (80, 80).
# Imagen sorpresa318esmesi.png redimensionada a (80, 80).
# Imagen sorpresa319esmesi.png redimensionada a (80, 80).
# Imagen sorpresa31esmesi.png redimensionada a (80, 80).
# Imagen sorpresa320esmesi.png redimensionada a (80, 80).
# Imagen sorpresa321esmesi.png redimensionada a (80, 80).
# Imagen sorpresa322esmesi.png redimensionada a (80, 80).
# Imagen sorpresa323esmesi.png redimensionada a (80, 80).
# Imagen sorpresa324esmesi.png redimensionada a (80, 80).
# Imagen sorpresa325esmesi.png redimensionada a (80, 80).
# Imagen sorpresa326esmesi.png redimensionada a (80, 80).
# Imagen sorpresa327esmesi.png redimensionada a (80, 80).
# Imagen sorpresa328esmesi.png redimensionada a (80, 80).
# Imagen sorpresa329esmesi.png redimensionada a (80, 80).
# Imagen sorpresa32esmesi.png redimensionada a (80, 80).
# Imagen sorpresa330esmesi.png redimensionada a (80, 80).
# Imagen sorpresa331esmesi.png redimensionada a (80, 80).
# Imagen sorpresa332esmesi.png redimensionada a (80, 80).
# Imagen sorpresa333esmesi.png redimensionada a (80, 80).
# Imagen sorpresa334esmesi.png redimensionada a (80, 80).
# Imagen sorpresa335esmesi.png redimensionada a (80, 80).
# Imagen sorpresa336esmesi.png redimensionada a (80, 80).
# Imagen sorpresa337esmesi.png redimensionada a (80, 80).
# Imagen sorpresa338esmesi.png redimensionada a (80, 80).
# Imagen sorpresa339esmesi.png redimensionada a (80, 80).
# Imagen sorpresa33esmesi.png redimensionada a (80, 80).
# Imagen sorpresa340esmesi.png redimensionada a (80, 80).
# Imagen sorpresa341esmesi.png redimensionada a (80, 80).
# Imagen sorpresa342esmesi.png redimensionada a (80, 80).
# Imagen sorpresa346esmesi.png redimensionada a (80, 80).
# Imagen sorpresa347esmesi.png redimensionada a (80, 80).
# Imagen sorpresa348esmesi.png redimensionada a (80, 80).
# Imagen sorpresa349esmesi.png redimensionada a (80, 80).
# Imagen sorpresa34esmesi.png redimensionada a (80, 80).
# Imagen sorpresa350esmesi.png redimensionada a (80, 80).
# Imagen sorpresa351esmesi.png redimensionada a (80, 80).
# Imagen sorpresa352esmesi.png redimensionada a (80, 80).
# Imagen sorpresa353esmesi.png redimensionada a (80, 80).
# Imagen sorpresa354esmesi.png redimensionada a (80, 80).
# Imagen sorpresa355esmesi.png redimensionada a (80, 80).
# Imagen sorpresa356esmesi.png redimensionada a (80, 80).
# Imagen sorpresa357esmesi.png redimensionada a (80, 80).
# Imagen sorpresa358esmesi.png redimensionada a (80, 80).
# Imagen sorpresa359esmesi.png redimensionada a (80, 80).
# Imagen sorpresa35esmesi.png redimensionada a (80, 80).
# Imagen sorpresa360esmesi.png redimensionada a (80, 80).
# Imagen sorpresa361esmesi.png redimensionada a (80, 80).
# Imagen sorpresa362esmesi.png redimensionada a (80, 80).
# Imagen sorpresa363esmesi.png redimensionada a (80, 80).
# Imagen sorpresa365esmesi.png redimensionada a (80, 80).
# Imagen sorpresa366esmesi.png redimensionada a (80, 80).
# Imagen sorpresa367esmesi.png redimensionada a (80, 80).
# Imagen sorpresa36esmesi.png redimensionada a (80, 80).
# Imagen sorpresa37esmesi.png redimensionada a (80, 80).
# Imagen sorpresa38esmesi.png redimensionada a (80, 80).
# Imagen sorpresa39esmesi.png redimensionada a (80, 80).
# Imagen sorpresa3esmesi.png redimensionada a (80, 80).
# Imagen sorpresa40esmesi.png redimensionada a (80, 80).
# Imagen sorpresa41esmesi.png redimensionada a (80, 80).
# Imagen sorpresa42esmesi.png redimensionada a (80, 80).
# Imagen sorpresa43esmesi.png redimensionada a (80, 80).
# Imagen sorpresa44esmesi.png redimensionada a (80, 80).
# Imagen sorpresa45esmesi.png redimensionada a (80, 80).
# Imagen sorpresa46esmesi.png redimensionada a (80, 80).
# Imagen sorpresa47esmesi.png redimensionada a (80, 80).
# Imagen sorpresa48esmesi.png redimensionada a (80, 80).
# Imagen sorpresa49esmesi.png redimensionada a (80, 80).
# Imagen sorpresa4esmesi.png redimensionada a (80, 80).
# Imagen sorpresa50esmesi.png redimensionada a (80, 80).
# Imagen sorpresa51esmesi.png redimensionada a (80, 80).
# Imagen sorpresa52esmesi.png redimensionada a (80, 80).
# Imagen sorpresa53esmesi.png redimensionada a (80, 80).
# Imagen sorpresa54esmesi.png redimensionada a (80, 80).
# Imagen sorpresa55esmesi.png redimensionada a (80, 80).
# Imagen sorpresa56esmesi.png redimensionada a (80, 80).
# Imagen sorpresa57esmesi.png redimensionada a (80, 80).
# Imagen sorpresa58esmesi.png redimensionada a (80, 80).
# Imagen sorpresa59esmesi.png redimensionada a (80, 80).
# Imagen sorpresa5esmesi.png redimensionada a (80, 80).
# Imagen sorpresa60esmesi.png redimensionada a (80, 80).
# Imagen sorpresa61esmesi.png redimensionada a (80, 80).
# Imagen sorpresa62esmesi.png redimensionada a (80, 80).
# Imagen sorpresa63esmesi.png redimensionada a (80, 80).
# Imagen sorpresa64esmesi.png redimensionada a (80, 80).
# Imagen sorpresa65esmesi.png redimensionada a (80, 80).
# Imagen sorpresa66esmesi.png redimensionada a (80, 80).
# Imagen sorpresa67esmesi.png redimensionada a (80, 80).
# Imagen sorpresa68esmesi.png redimensionada a (80, 80).
# Imagen sorpresa69esmesi.png redimensionada a (80, 80).
# Imagen sorpresa6esmesi.png redimensionada a (80, 80).
# Imagen sorpresa70esmesi.png redimensionada a (80, 80).
# Imagen sorpresa71esmesi.png redimensionada a (80, 80).
# Imagen sorpresa72esmesi.png redimensionada a (80, 80).
# Imagen sorpresa73esmesi.png redimensionada a (80, 80).
# Imagen sorpresa74esmesi.png redimensionada a (80, 80).
# Imagen sorpresa75esmesi.png redimensionada a (80, 80).
# Imagen sorpresa76esmesi.png redimensionada a (80, 80).
# Imagen sorpresa77esmesi.png redimensionada a (80, 80).
# Imagen sorpresa78esmesi.png redimensionada a (80, 80).
# Imagen sorpresa79esmesi.png redimensionada a (80, 80).
# Imagen sorpresa7esmesi.png redimensionada a (80, 80).
# Imagen sorpresa80esmesi.png redimensionada a (80, 80).
# Imagen sorpresa81esmesi.png redimensionada a (80, 80).
# Imagen sorpresa82esmesi.png redimensionada a (80, 80).
# Imagen sorpresa83esmesi.png redimensionada a (80, 80).
# Imagen sorpresa84esmesi.png redimensionada a (80, 80).
# Imagen sorpresa85esmesi.png redimensionada a (80, 80).
# Imagen sorpresa86esmesi.png redimensionada a (80, 80).
# Imagen sorpresa87esmesi.png redimensionada a (80, 80).
# Imagen sorpresa89esmesi.png redimensionada a (80, 80).
# Imagen sorpresa8esmesi.png redimensionada a (80, 80).
# Imagen sorpresa90esmesi.png redimensionada a (80, 80).
# Imagen sorpresa91esmesi.png redimensionada a (80, 80).
# Imagen sorpresa92esmesi.png redimensionada a (80, 80).
# Imagen sorpresa93esmesi.png redimensionada a (80, 80).
# Imagen sorpresa94esmesi.png redimensionada a (80, 80).
# Imagen sorpresa95esmesi.png redimensionada a (80, 80).
# Imagen sorpresa96esmesi.png redimensionada a (80, 80).
# Imagen sorpresa97esmesi.png redimensionada a (80, 80).
# Imagen sorpresa98esmesi.png redimensionada a (80, 80).
# Imagen sorpresa99esmesi.png redimensionada a (80, 80).
# Imagen sorpresa9esmesi.png redimensionada a (80, 80).
